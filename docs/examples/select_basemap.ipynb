# %%
import bassmap
from bassmap import Mapomatic

# %%
m = Mapomatic(center=[0, 0], zoom=2)
m.select_basemap()
m
# Out:
# Mapomatic(center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\bassn\miniconda3\envs\geos\lib\site-packages\ipywidgets\widgets\widget.py:676, in Widget._handle_msg(self, msg)
#     674         if 'buffer_paths' in data:
#     675             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676         self.set_state(state)
#     678 # Handle a state request.
#     679 elif method == 'request_state':
#
# File c:\Users\bassn\miniconda3\envs\geos\lib\site-packages\ipywidgets\widgets\widget.py:545, in Widget.set_state(self, sync_data)
#     542 if name in self.keys:
#     543     from_json = self.trait_metadata(name, 'from_json',
#     544                                     self._trait_from_json)
# ...
